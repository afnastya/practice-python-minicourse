# %%
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://briefly.ru'

# %%
responce = requests.get(url + '/authors/')
soup = BeautifulSoup(responce.content, 'html.parser')

# %%
authors_html_block = soup.find('div', 'alphabetic-index')
authors = authors_html_block.find_all('a')

# %%
authors_codes2names = dict()
author_codes = []

for author in authors:
    if 'surnames' not in author['href']:
        author_codes.append(author['href'])
        authors_codes2names[author['href']] = author.text
        continue
    
    surnames_responce = requests.get(url + author['href'])
    surnames_soup = BeautifulSoup(surnames_responce.content, 'html.parser')
    
    for author_html_block in surnames_soup.find_all('div', 'author'):
        author_code = author_html_block.find('a')['href']
        author_codes.append(author_code)
        authors_codes2names[author_code] = author.text

# %%
# блок может работать до 5 - 10 минут
main_tags = []
book_titles = []
book_authors = []
book_years = []
book_tags = []
book_summary_urls = []
book_original_urls = []
book_texts = []

for author_code in author_codes:
    print(author_code)

    author_responce = requests.get(url + author_code)
    author_soup = BeautifulSoup(author_responce.content, 'html.parser')

    author_name = author_soup.find('span', 'author_name normal'
                                   if author_soup.find('span', 'author_name normal') else 'author_name long').text.replace('\xa0', ' ')

    tags = [tag.text.replace('\xa0', ' ') for tag in author_soup.find('ol', 'breadcrumbs-compact').find_all('span')]
    main_tags.append(tags[0])

    # если у автора нет книг
    if author_soup.find('section', "author_works").find('div', 'noworks'):
        continue

    # определяем есть ли на странице блок "все пересказы по алфавиту"
    if author_soup.find('section', "works_index"):
        has_works_index_section = True
        book_html_blocks = author_soup.find('section', "works_index").find_all('li')
    else:
        has_works_index_section = False
        book_html_blocks = author_soup.find('section', 'author_works').find_all('div', 'w-featured')

    # перебираем все книги автора
    for book_html_block in book_html_blocks:
        if "requested" in book_html_block['class'] or "pending" in book_html_block['class']:
            continue
        
        book_code = book_html_block.find('a')['href']

        # переходим на суп страницы с книгой
        book_responce = requests.get(url + book_code)
        book_soup = BeautifulSoup(book_responce.content, 'html.parser')

        # парсим краткое содержание
        book_paragraphs = []
        if book_soup.find('p', 'microsummary'):
            book_paragraphs.append(book_soup.find('p', 'microsummary').get_text())
        book_paragraphs.extend([paragraph.text
                               for paragraph in book_soup.find('div', id='text').find_all(['h2', 'h3', 'p', 'blockquote', 'li'])])
        text = '\n'.join(book_paragraphs).replace('\xad', '').replace('\xa0', ' ')
        book_texts.append(text)
        
        # добавляем всю остальную информации по книге
        book_tag = book_soup.find('div', 'breadcrumb__content').text.replace('\xa0', ' ')
        main_tags.append(book_tag)
        book_tags.append(', '.join(tags + [book_tag]))
        book_authors.append(author_name)
        book_years.append(book_soup.find('span', 'date').text if book_soup.find('span', 'date') else None)
        book_summary_urls.append(url + book_code)
        book_original_urls.append(book_soup.find('div', 'readingtime').find('a')['href']
                                  if book_soup.find('div', 'readingtime').find('a')
                                  else None)
        book_titles.append(book_html_block.find('a').text.replace('\xa0', ' ')
                           if has_works_index_section
                           else book_html_block.find('div', 'w-title').text.replace('\xa0', ' '))
# Out:
# /abgarian/
# /abdullaev/
# /ablesimov/
# /abramov/
# /sergey_abramov/
# /abu_bakar/
# /abe/
# /avvakum/
# /avgustin/
# /averchenko/
# /avi_shaul/
# /avreliy/
# /agarunov/
# /ageev/
# /adamov/
# /adamovich/
# /adams/
# /adamchik/
# /adizes/
# /alfred_adler/
# /adler/
# /adra/
# /azimov/
# /azolskiy/
# /aisse/
# /ayzekson/
# /aymauytov/
# /ayni/
# /ajtmatov/
# /akroyd/
# /aksakov/
# /aksenov/
# /akunin/
# /akutagava/
# /aldanov/
# /aleksandrova/
# /alekseev/
# /st_alekseev/
# /aleksievich/
# /aleksin/
# /aleshkovskij/
# /aligeri/
# /alimzhanov/
# /allen/
# /almazov/
# /almond/
# /alende/
# /altshuller/
# /alferi/
# /amadu/
# /amonashvili/
# /anar/
# /andersen/
# /anderson/
# /chris_anderson/
# /underhill/
# /andievskaia/
# /andreev/
# /daniil_andreev/
# /andrich/
# /annenskiy/
# /antarova/
# /antonov/
# /anuj/
# /apdajk/
# /apolliner/
# /apulej/
# /aragon/
# /arbetnot/
# /arbuzov/
# /aretino/
# /arieli/
# /ariosto/
# /aristotel/
# /aristofan/
# /armstrong/
# /aromshtam/
# /arsenev/
# /artur/
# /arhangelsky/
# /arcybashev/
# /astafev/
# /asturias/
# /auezov/
# /afanasev/
# /akhern/
# /ahmatova/
# /akhundov/
# /suleyman_sani_akhundov/
# /achebe/
# /ashvaghosha/
# /babel/
# /babur/
# /bagrianyy/
# /bazhov/
# /bazen/
# /bazorkin/
# /baydzhiev/
# /bajron/
# /baklanov/
# /bakman/
# /balter/
# /balzak/
# /balmont/
# /bana/
# /ban_gu/
# /benjan/
# /bar/
# /bar_yosef/
# /baratynsky/
# /barberi/
# /barbjus/
# /bardugo/
# /barikko/
# /barns/
# /baroha-i-nessi/
# /barri/
# /barsov/
# /barto/
# /baruzdin/
# /barshchevskiy/
# /basova/
# /batyrev/
# /batiushkov/
# /baum/
# /bakh/
# /bakhtin/
# /zinger/
# /baialinov/
# /begbeder/
# /bednyy/
# /bede/
# /beyshenaliev/
# /bek/
# /bekker/
# /bekket/
# /belinskiy/
# /bellou/
# /bell/
# /belov/
# /belsky/
# /belyj/
# /belger/
# /beljaev/
# /beliaev_vp/
# /belianin/
# /ben_shakhar/
# /benavente/
# /benn/
# /bentconi/
# /berggoltc/
# /bergman/
# /berdzhess/
# /berdiaev/
# /berzherak/
# /bern/
# /bernanos/
# /sen-per/
# /bernett/
# /berns/
# /bernstayn/
# /edgar_rays_berrouz/
# /berrouz/
# /birsel/
# /besson/
# /bestuzhev/
# /bzhekhva/
# /bianki/
# /biber/
# /bikchentaev/
# /bioy_kasares/
# /birs/
# /bitov/
# /bicher-stou/
# /bichuia/
# /bien/
# /blayton/
# /blanchard/
# /ibanes/
# /bleyk/
# /blok/
# /bo_sinczjan/
# /bo_pu/
# /boborykin/
# /bovuar/
# /bogdanov/
# /bogdanovich/
# /bogl/
# /bogomolov/
# /bodler/
# /bodriyiar/
# /boyn/
# /bokkachcho/
# /bokov/
# /bolduin/
# /bolls/
# /bomarshe/
# /bondarev/
# /bono/
# /borgen/
# /borovikova/
# /sergey_borodin/
# /borodin/
# /borhes/
# /bouden/
# /bouler/
# /bouen/
# /bragin/
# /branner/
# /brant/
# /frederik_braun/
# /braun/
# /bregman/
# /brentano/
# /breton/
# /breht/
# /brodele/
# /brodskij/
# /brojn/
# /broyning/
# /bronson/
# /bronte/
# /emilibronte/
# /enn_bronte/
# /broh/
# /brooks/
# /brushteyn/
# /bryl/
# /bredberi/
# /bredli/
# /brenson/
# /brjusov/
# /briussolo/
# /bualo/
# /buyda/
# /bukovski/
# /bulatov/
# /bulgakov/
# /bulychev/
# /bunin/
# /burla/
# /bussenar/
# /butromeev/
# /buccati/
# /bhavabhuti/
# /bharavi/
# /bhasa/
# /bykov/
# /dmitriy_bykov/
# /bekon/
# /benks/
# /bjurger/
# /bjutor/
# /buettner/
# /bjuhner/
# /biadulia/
# /vaal/
# /vaginov/
# /vagner/
# /vaynerchuk/
# /vaynery/
# /vajs/
# /weiss/
# /valdshmidt/
# /vale-inklan/
# /valzer/
# /valmiki/
# /vampilov/
# /losa/
# /vasilevich/
# /vasilevskaia/
# /vasilenko/
# /vasilev/
# /vasserman/
# /vatsyayana/
# /vebb/
# /veber/
# /vebster/
# /vega/
# /vezhinov/
# /vezirov/
# /veller/
# /veltistov/
# /veltman/
# /veras/
# /verber/
# /verga/
# /vergeze/
# /vergilij/
# /vereyskaia/
# /verenitcyn/
# /veresaev/
# /verkin/
# /vern/
# /vesos/
# /vestover/
# /vian/
# /vigasin/
# /viland/
# /villink/
# /vilmont/
# /vingranovskiy/
# /vinnichenko/
# /vinnichuk/
# /vinogradov/
# /vini/
# /rizwan/
# /vitgenshteyn/
# /vitka/
# /vitcher/
# /vishakhadatta/
# /vsevolod_vishnevskiy/
# /vishnevskiy/
# /vladimov/
# /vo/
# /vovenarg/
# /vovchok/
# /vodolazkin/
# /voznesenskaia/
# /voznesenskij/
# /voynich/
# /vojnovich/
# /volkov/
# /volodin/
# /volskiy/
# /volter/
# /volf/
# /vonnegut/
# /vordsvort/
# /vorobiev/
# /voronina/
# /voronkova/
# /voronoy/
# /voskoboynikov/
# /vronskiy/
# /vrochek/
# /vudhauz/
# /vuychich/
# /virg-vulf/
# /vulf/
# /vysotckiy/
# /viasa/
# /vens/
# /gabbe/
# /gabova/
# /gavalda/
# /gavande/
# /gavrosh/
# /gagloev/
# /gadiev/
# /gazdanov/
# /gaipov/
# /gajdar/
# /gal/
# /galego/
# /gamzatov/
# /gamilton/
# /gamsun/
# /gandri/
# /maoqing/
# /gao/
# /gar/
# /hardy/
# /gardner/
# /gari/
# /garin-mihajlovskij/
# /garrison/
# /lorka/
# /markes/
# /gart/
# /garshin/
# /gaskell/
# /gasparov/
# /gauptman/
# /gauf/
# /gashek/
# /gegel/
# /gej/
# /gejm/
# /geyman/
# /gejne/
# /geyts/
# /geliodor/
# /gelprin/
# /gelderlin/
# /genri/
# /geraskina/
# /gerber/
# /gerbert/
# /german/
# /gerodot/
# /gert/
# /gercen/
# /gershenzon/
# /gesiod/
# /gesse/
# /gete/
# /gibson/
# /gijerag/
# /gilbert/
# /gilevich/
# /guillebeau/
# /gilferding/
# /giliarovskiy/
# /ginzburg/
# /gippenreyter/
# /gippius/
# /gir/
# /gitler/
# /gladkov/
# /gladuell/
# /glukhovskiy/
# /gobbs/
# /gogol/
# /godvin/
# /godin/
# /gojtisolo/
# /golden/
# /golding/
# /goldratt/
# /goldsmit/
# /goldsmith/
# /golitcyn/
# /golovachev/
# /golon/
# /golsuorsi/
# /goldoni/
# /goliavkin/
# /gomer/
# /gongora-i-argote/
# /gonkur/
# /gonchar/
# /goncharov/
# /goratciy/
# /gorbatov/
# /gorder/
# /gorenshtejn/
# /gorin/
# /gorkii/
# /gotorn/
# /gottman/
# /gote/
# /goulman/
# /goulston/
# /gofman/
# /gofmanstal/
# /gocci/
# /granin/
# /grasian-i-morales/
# /grass/
# /greger/
# /grekova/
# /griboedov/
# /grigorovich/
# /grilparcer/
# /grimm/
# /grimmelsgauzen/
# /grin/
# /gremgrin/
# /rodzher_grin/
# /robert_grin/
# /dzhon_grin/
# /grinvud/
# /groznyy/
# /gromova/
# /grossman/
# /david_grossman/
# /grum/
# /grey/
# /kennet_grem/
# /bendzhamin_grem/
# /grem/
# /guan_hancin/
# /gubarev/
# /gudkaynd/
# /guliam/
# /gumilev/
# /lev_gumilev/
# /gusev/
# /gusovskiy/
# /gutcalo/
# /gelliko/
# /gugo/
# /gjuismans/
# /guntekin/
# /nizami/
# /denis_davydov/
# /davydov/
# /davydychev/
# /dadzay/
# /shanfu/
# /dayneko/
# /dalidovich/
# /dalio/
# /vladimir_dal/
# /dal/
# /darvin/
# /darrell/
# /dakhigg/
# /dashvar/
# /dashevskaia/
# /dashkova/
# /deblin/
# /degtev/
# /dekart/
# /delibes/
# /delillo/
# /demosfen/
# /derzhavin/
# /defo/
# /dzhabbarly/
# /dzhavid/
# /dzhalil/
# /jarvis/
# /dzhajadeva/
# /meg_jay/
# /dzhejms/
# /e_l_dzheyms/
# /dzherom/
# /dzhio/
# /dzhirard/
# /dzhovanoli/
# /dzhojs/
# /dzhons/
# /diana_uinn_dzhons/
# /ben_dzhonson/
# /dzhonson/
# /siu_dzhonson/
# /diamandis/
# /didro/
# /dik/
# /dikamillo/
# /dikkens/
# /dimarov/
# /dispenza/
# /dmitriev/
# /dobroljubov/
# /dobychin/
# /dovzhenko/
# /dovlatov/
# /dode/
# /dodzh/
# /dojl/
# /dokinz/
# /doktorou/
# /doman/
# /dombrovskij/
# /dontcova/
# /passos/
# /dostoevsky/
# /dotsouk/
# /dragunskiy/
# /drajzer/
# /drozd/
# /druzhinin/
# /druker/
# /drukerman/
# /drutce/
# /drebl/
# /drjuon/
# /dubov/
# /dudarev/
# /dudincev/
# /dumbadze/
# /dunin_martcinkevich/
# /dweck/
# /deshner/
# /djuma/
# /diumore/
# /djuras/
# /djurrenmatt/
# /dannuncio/
# /evripid/
# /evtushenko/
# /ekimov/
# /elizarov/
# /elinek/
# /emetc/
# /enal/
# /enikeev/
# /premudryy/
# /ermakov/
# /yermolay/
# /erofeev/
# /viktor_erofeev/
# /eroshenko/
# /ershov/
# /esenberlin/
# /esenin/
# /efremov/
# /zhvalevskiy/
# /zheleznikov/
# /zheliazny/
# /zhene/
# /zheromskij/
# /zhigulin/
# /zhid/
# /zhirodu/
# /zhitkov/
# /zhuk/
# /zhukov/
# /zhukovsky/
# /zhunusov/
# /zabolotckiy/
# /zagosky/
# /zagrebelnyy/
# /zadornov/
# /zaytcev/
# /zakrutkin/
# /zalygin/
# /zalten/
# /zamyatin/
# /zaretckiy/
# /zasodimskiy/
# /zatochnik/
# /zakhariadis/
# /zaher-mazoh/
# /zakhoder/
# /zvezdnaia/
# /zverev/
# /zegers/
# /zeland/
# /zimbardo/
# /zinsser/
# /zlobin/
# /zolja/
# /zorin/
# /zoshenko/
# /zuzak/
# /zjuskind/
# /ibragimbekov/
# /ibragimov/
# /kanta_ibragimov/
# /ibsen/
# /ibuka/
# /ivanov/
# /anatoliy_ivanov/
# /aleksey_ivanov/
# /ivanov_ustinova/
# /ivashkevich/
# /hilarion/
# /ilina/
# /ilfipetrov/
# /iliakhov/
# /ionesko/
# /ipatova/
# /irving/
# /dzhon_irving/
# /isakovskiy/
# /isaiama/
# /isiguro/
# /iskander/
# /ishimova/
# /jensen/
# /irasek/
# /yokai/
# /yohn/
# /kabakov/
# /kavabata/
# /kavasaki/
# /kaverin/
# /kadyri/
# /kazakevich/
# /kazakov/
# /kazanova/
# /kazantcev/
# /kazantceva/
# /kazot/
# /kaysenov/
# /kaku/
# /kalashnikov/
# /kalidasa/
# /kalinin/
# /kalvino/
# /kalderon/
# /kamal/
# /kamoens/
# /kampanella/
# /kamju/
# /kaneman/
# /kanetti/
# /kant/
# /kantemir/
# /kapnist/
# /kapote/
# /karamazov/
# /karamzin/
# /kard/
# /karim/
# /karlgaard/
# /karnegi/
# /karpenko_karyy/
# /karpenter/
# /karr/
# /karter/
# /kasparov/
# /kassil/
# /kastaneda/
# /kataev/
# /katull/
# /bel_kaufman/
# /kaufman/
# /kafka/
# /kakhkhar/
# /kashchenko/
# /kvitka_osnovianenko/
# /kevedo/
# /kedrin/
# /kejn/
# /keyn/
# /keller/
# /kellerman/
# /kenilli/
# /kennedy/
# /kennedi/
# /keno/
# /kerashev/
# /kerbabaev/
# /kervud/
# /keruak/
# /kestler/
# /kestner/
# /ketlinskaia/
# /kehoe/
# /keshokov/
# /kiz/
# /kizi/
# /kiyosaki/
# /iuliy_kim/
# /kim/
# /kim_vichan/
# /kin/
# /king/
# /kipling/
# /kireev/
# /kiselev/
# /kisimoto/
# /klavell/
# /klayn/
# /klark/
# /kleyson/
# /klejst/
# /kleon/
# /klepov/
# /klir/
# /klodel/
# /klopshtok/
# /klychkov/
# /kler/
# /knorre/
# /kniazhnin/
# /kobylianskaia/
# /koval/
# /kovi/
# /kozhevnikov/
# /viliam_kozlov/
# /kozlov/
# /kokovin/
# /kokto/
# /kolas/
# /kolett/
# /kollinz/
# /jim_collins/
# /siuzen_kollinz/
# /kolfer/
# /kolridzh/
# /koliada/
# /kongriv/
# /kondo/
# /kondratev/
# /konetckiy/
# /konrad/
# /konstan/
# /confucius/
# /korelli/
# /korzhikov/
# /kornel/
# /korolenko/
# /koroliv/
# /korolkov/
# /korotkevich/
# /korotkov/
# /kortasar/
# /korchak/
# /kosmovskaia/
# /kosmodemianskaia/
# /kostenko/
# /koster/
# /kotler/
# /kotliarevskiy/
# /kouplend/
# /kouton/
# /kouell/
# /kokh/
# /kotciubinskiy/
# /koelo/
# /krayton/
# /kramer/
# /krapiva/
# /krapivin/
# /krasnov/
# /krauss/
# /krebijon-syn/
# /krestovskij/
# /kleyton_kristensen/
# /kristensen/
# /kristi/
# /kronin/
# /krouli/
# /krug/
# /krupin/
# /krylov/
# /kriukova/
# /krius/
# /kudravetc/
# /agniia_kuznetcova/
# /kuznetcova/
# /kuliev/
# /kulish/
# /kun/
# /kunanbaev/
# /kundera/
# /kunin/
# /kupala/
# /kuper/
# /alan_kuper/
# /kuprin/
# /kuritcyn/
# /kurochkin/
# /kurpatov/
# /kutzee/
# /kutuy/
# /kerkegor/
# /kiuban/
# /kemeron/
# /kemp/
# /kempbell/
# /kolin_kempbell/
# /keri/
# /kerroll/
# /labkovskiy/
# /labrjujer/
# /lavkraft/
# /lavrenev/
# /lagerkvist/
# /lagerlef/
# /lagin/
# /lazhechnikov/
# /layker/
# /laklo/
# /laksness/
# /lalu/
# /lamur/
# /lane/
# /lao_she/
# /lao_tczy/
# /larni/
# /larri/
# /larssen/
# /larsson/
# /lafajet/
# /lafonten/
# /latcis/
# /le_guin/
# /karre/
# /leal/
# /leblan/
# /levi/
# /levy/
# /levinson/
# /levitt/
# /levitckiy/
# /levshin/
# /igor_levshin/
# /lederman/
# /lem/
# /lenglend/
# /lenin/
# /lennrot/
# /lensioni/
# /lenc/
# /leonov/
# /lepkiy/
# /lermontov/
# /leru/
# /lesazh/
# /leskov/
# /lessing/
# /li_fujan/
# /li_gunczo/
# /wengyui/
# /qzhifu/
# /li_chzhen/
# /li_juj/
# /sten_li/
# /li/
# /brius_li/
# /lidin/
# /limonov/
# /lin_menchu/
# /lindberg/
# /lindgren/
# /linevskiy/
# /linch/
# /lipatov/
# /lipskerov/
# /lir/
# /likhanov/
# /likhachev/
# /likhonosov/
# /logan/
# /lokk/
# /lomonosov/
# /long/
# /longfello/
# /london/
# /lotman/
# /lourens/
# /louri/
# /louson/
# /lu/
# /luzhanin/
# /lukian/
# /lukin/
# /lukretciy/
# /lukianenko/
# /luts/
# /lynkov/
# /ljuis/
# /liuis/
# /devid_liuis/
# /lewis/
# /le_shi/
# /lju_fu/
# /ma_chzhijuan/
# /mavr/
# /magha/
# /may/
# /mayer/
# /maikov/
# /mejrink/
# /makanin/
# /makarenko/
# /mcgee/
# /makgonigal/
# /makiavelli/
# /makkalers/
# /makkalou/
# /makkarti/
# /mckeown/
# /maknot/
# /maksimov/
# /max_maximov/
# /makiuen/
# /malik/
# /khabilov/
# /galina_malik/
# /malo/
# /malro/
# /maliavin/
# /mamakaev/
# /mamedkulizade/
# /mamin-sibirjak/
# /mamleev/
# /mandelshtam/
# /mandzoni/
# /mann/
# /tomasmann/
# /igor_mann/
# /shamplen-marivo/
# /mariengof/
# /marinina/
# /marion/
# /marks/
# /marlo/
# /martel/
# /martin/
# /martinson/
# /martynov/
# /marsh/
# /marshak/
# /marshall/
# /maslou/
# /mass/
# /mastriukova/
# /matveev/
# /matinskii/
# /matiushkina/
# /mashkov/
# /majakovskij/
# /medvedev/
# /medina/
# /mejer/
# /mejler/
# /melvill/
# /melezh/
# /mele/
# /melnikov/
# /menandr/
# /menzatiuk/
# /merdok/
# /merezhkovskij/
# /merime/
# /merl/
# /merse/
# /merton/
# /metastazio/
# /meterlink/
# /miller/
# /miller2/
# /miln/
# /milton/
# /minaev/
# /minto/
# /mintcberg/
# /mirnyy/
# /misima/
# /misko/
# /mitchell/
# /devid_mitchell/
# /mikhalkov/
# /mikhasenko/
# /mikheeva/
# /mickevich/
# /mlodinov/
# /mo_yan/
# /modiano/
# /mozhaev/
# /moyes/
# /molina/
# /moler/
# /momyshuly/
# /monomakh/
# /montgomeri/
# /monten/
# /monteske/
# /mopassan/
# /mor/
# /moravia/
# /mori/
# /moriak/
# /moritc/
# /morrison/
# /morua/
# /moskvina/
# /moshkovskiy/
# /moem/
# /muberg/
# /mudryy/
# /muzil/
# /mukanov/
# /munk/
# /murakami/
# /riu_murakami/
# /murasaki/
# /murataliev/
# /murashova/
# /musrepov/
# /mukhina_petrinskaia/
# /mushinskaia/
# /mushfig/
# /melori/
# /menson/
# /metison/
# /metjurin/
# /mjusse/
# /miusso/
# /nabokov/
# /navarrskaja/
# /navoi/
# /navolochkin/
# /nagibin/
# /nadezhdina/
# /nazarkin/
# /nazaruk/
# /naim/
# /nayt/
# /nareznyi/
# /narekaci/
# /narokov/
# /naumenko/
# /soseki/
# /neverov/
# /nekrasov/
# /andrey_nekrasov/
# /nekrasovvp/
# /neruda/
# /nesbe/
# /nesbit/
# /nestayko/
# /nestlinger/
# /nestor_letopisetc/
# /nestor-iskander/
# /nechuy_levitckiy/
# /nidze/
# /nikitin/
# /nikolev/
# /nikonov/
# /nilin/
# /nitcshe/
# /novalis/
# /novikov/
# /novikov_priboy/
# /novoselov/
# /node/
# /norman/
# /norris/
# /nikolainosov/
# /nosov/
# /nurpeisov/
# /nushich/
# /niumark/
# /newport/
# /oakli/
# /obruchev/
# /ovechkin/
# /nazon/
# /odoevsky/
# /odoevtceva/
# /ozheshko/
# /ozerov/
# /okudzhava/
# /olbi/
# /oldi/
# /oldington/
# /oldridzh/
# /aulet/
# /olesha/
# /oliver/
# /olkott/
# /ordubadi/
# /orlov/
# /oruell/
# /osborn/
# /oseeva/
# /osmonov/
# /osorgin/
# /oster/
# /ostin/
# /ostrovskij/
# /nikolaiostrovskij/
# /outs/
# /osho/
# /oe/
# /o_keysi/
# /okonnor/
# /onil/
# /ofaolejn/
# /paveze/
# /pavich/
# /pavlenko/
# /palanik/
# /palasio/
# /palomnik/
# /pamuk/
# /panteleev/
# /panchin/
# /panol/
# /paolini/
# /parr/
# /paskal/
# /pasternak/
# /e_pasternak/
# /pattu/
# /paustovskij/
# /pelevin/
# /pennak/
# /pennipaker/
# /peres_reverte/
# /peresvetov/
# /perkins/
# /perlmutter/
# /permiak/
# /perro/
# /perumov/
# /petranovskaia/
# /petrarka/
# /petronij/
# /petrosian/
# /petrushevskaja/
# /pivovarova/
# /pidmogilnyy/
# /piz/
# /piketti/
# /pikolt/
# /pikul/
# /pilnjak/
# /pink/
# /pinker/
# /pinter/
# /pinchon/
# /pirandello/
# /pisarev/
# /pisakhov/
# /pisemskij/
# /piters/
# /piterson/
# /plavilshchikov/
# /plavt/
# /platon/
# /platonov/
# /plencdorf/
# /plutarx/
# /po/
# /pogodin/
# /pogorelskij/
# /polevoy/
# /polezhaev/
# /pollan/
# /polotckiy/
# /poluektov/
# /poliakov/
# /poliarnyy/
# /pomjalovskij/
# /mi_popov/
# /popov/
# /elinor_porter/
# /porter/
# /pototckiy/
# /poup/
# /pravdukhin/
# /prayor/
# /pratchett/
# /prevo/
# /prilepin/
# /prist/
# /pristavkin/
# /pristli/
# /prichard/
# /prishvin/
# /proysler/
# /prokopovich/
# /prokofeva/
# /prus/
# /prust/
# /ptashnikov/
# /pu_sunlin/
# /pulman/
# /pushkin/
# /pushchin/
# /petcukh/
# /pjuzo/
# /rable/
# /radzievskaia/
# /radzinskij/
# /radicshev/
# /ryan/
# /raynis/
# /rampo/
# /rasiel/
# /rasin/
# /raspe/
# /rasputin/
# /rassel/
# /raud/
# /raffi/
# /rekkhem/
# /remark/
# /rembo/
# /remizov/
# /rerikh/
# /reshetnikov/
# /riggz/
# /rid/
# /ridi/
# /rilke/
# /riordan/
# /ripli/
# /ris/
# /richardson/
# /rob-grije/
# /robbins/
# /roberts/
# /robinson/
# /rodari/
# /rodosskij/
# /rozhdestvenskiy/
# /rozanov/
# /rosenzweig/
# /rozov/
# /arundati_roy/
# /roy/
# /rollan/
# /rollins/
# /romanova/
# /roni/
# /ronshin/
# /rostan/
# /rot/
# /filip_rot/
# /veronika_rot/
# /rotterdamskij/
# /roudz/
# /rouling/
# /rocshin/
# /rubina/
# /rublevskaia/
# /rubtcov/
# /rudashevskiy/
# /safon/
# /rumelt/
# /russo/
# /rustaveli/
# /rutkovskiy/
# /rushdi/
# /rybakov/
# /ryleev/
# /rytkheu/
# /rend/
# /rjutbef/
# /sabatini/
# /sabitova/
# /karl_sagan/
# /sagan/
# /sagg/
# /sad/
# /sazerlend/
# /kurban_said/
# /sajkaku/
# /sajmak/
# /sakketti/
# /saks/
# /sallivan/
# /saltykov-cshedrin/
# /salgari/
# /samarskiy/
# /samoylov/
# /sanaev/
# /sangi/
# /sand/
# /sapkovskiy/
# /sapolski/
# /saramago/
# /sarojan/
# /sarrot/
# /sartr/
# /satton/
# /safarli/
# /svintcov/
# /svirskiy/
# /svift/
# /sederberg/
# /seyfullina/
# /sela/
# /seligman/
# /selimovich/
# /selin/
# /semenov/
# /semenova/
# /semin/
# /seneka/
# /senkevich/
# /sent-ekzjuperi/
# /senchin/
# /serafimovich/
# /servantes/
# /sergeev_tcenskiy/
# /seton-tompson/
# /setterfild/
# /sibold/
# /sigal/
# /sigel/
# /sillov/
# /silvestr/
# /simashko/
# /simenon/
# /simmons/
# /annet_simmons/
# /simon/
# /simonov/
# /sinek/
# /sinkler/
# /sinsero/
# /sinjavskij/
# /sitnikov/
# /skarron/
# /skott/
# /skrebitckiy/
# /skrib/
# /sladkov/
# /slovackij/
# /smirnov/
# /smirnova/
# /smit/
# /betti_smit/
# /liza_dzheyn_smit/
# /smoll/
# /smollet/
# /snegirev/
# /snou/
# /sobolev/
# /nikolay_sobolev/
# /sokolov/
# /sokolov_mikitov/
# /sokolov_mitrich/
# /sokpakbaev/
# /solzhenitsyn/
# /sollogub/
# /solovev/
# /sologub/
# /soloukhin/
# /sorel/
# /sorokin/
# /sorotokina/
# /sosnora/
# /sotnik/
# /sofokl/
# /sofroniy_ierusalimskiy/
# /spark/
# /sparks/
# /spinoza/
# /stayn/
# /stajron/
# /stal/
# /stanjukovich/
# /staritckiy/
# /stark/
# /staut/
# /stejnbek/
# /stelmakh/
# /iaroslav_stelmakh/
# /stendal/
# /stepnova/
# /stern/
# /stivenson/
# /steel/
# /stil/
# /stoker/
# /stoppard/
# /storozhenko/
# /stoun/
# /stone/
# /strank/
# /straparola/
# /straud/
# /straffi/
# /streltcov/
# /strindberg/
# /strugackie/
# /stenli/
# /subandhu/
# /suvorov/
# /suleymenov/
# /sulitcer/
# /sumarokov/
# /sun_zi/
# /surikov/
# /suhovo-kobylin/
# /sukhomlinskiy/
# /anna_siuell/
# /siuell/
# /senagon/
# /selindzher/
# /sendberg/
# /sju/
# /tagor/
# /tayson/
# /takami/
# /taleb/
# /reo/
# /tammsaare/
# /dzjunitiro/
# /tartt/
# /tasso/
# /tatij/
# /taunsend/
# /tashmukhamedov/
# /tvardovskij/
# /tven/
# /tegner/
# /tekkerej/
# /teleshov/
# /temei/
# /tendrjakov/
# /tepfer/
# /afr/
# /tik/
# /mondzaemon/
# /til/
# /titov/
# /bendzhamin_todd/
# /todd/
# /tokareva/
# /tokmakova/
# /tolkien/
# /tolstaia/
# /tolstoiak/
# /tolstoi/
# /tolstoian/
# /tomin/
# /tompson/
# /topelius/
# /tor/
# /torik/
# /toro/
# /toffler/
# /tramp/
# /traub/
# /traut/
# /trediakovskii/
# /tracy/
# /trenev/
# /tretiakov/
# /triole/
# /trifonov/
# /troepolskiy/
# /troye/
# /trublaini/
# /trevers/
# /tukay/
# /tulgan/
# /tumanian/
# /turgenev/
# /turne/
# /turovskiy/
# /turold/
# /tynjanov/
# /teffi/
# /tiutchev/
# /tiutiunnik/
# /hanchen/
# /u_chenen/
# /uajlder/
# /uajld/
# /uayt/
# /uajt/
# /uglov/
# /uzuner/
# /uilson/
# /uiljams/
# /williams/
# /uir/
# /uitmen/
# /ukrainka/
# /ulitckaia/
# /umarbekov/
# /unamuno/
# /unset/
# /walker/
# /uolles/
# /uolpol/
# /walsh/
# /uorren/
# /warrillow/
# /uorton/
# /urnov/
# /usachev/
# /nikolay_uspenskiy/
# /uspenskij/
# /lev_uspenskiy/
# /uspenskiy/
# /ustinova/
# /ushinskiy/
# /uejn/
# /uells/
# /uelch/
# /uelsh/
# /uelbek/
# /faber/
# /fadeev/
# /fayzi/
# /fallada/
# /fardzhon/
# /farker/
# /faulz/
# /fedin/
# /fedorenko/
# /feynman/
# /fejhtvanger/
# /mot-fenelon/
# /feokrit/
# /ferratctci/
# /ferriss/
# /fet/
# /fizuli/
# /filatov/
# /filding/
# /filippo/
# /filips/
# /firdousi/
# /ficdzherald/
# /fisher/
# /flinn/
# /flober/
# /flegg/
# /foer/
# /folkner/
# /follett/
# /fonvizin/
# /fontane/
# /foniakova/
# /ford/
# /forester/
# /forman/
# /forsh/
# /foskolo/
# /fraerman/
# /fray/
# /frayd/
# /frank/
# /anna_frank/
# /frankl/
# /franko/
# /frans/
# /frey/
# /freyd/
# /frish/
# /fromm/
# /frensis/
# /fuke/
# /funke/
# /furmanov/
# /fuchik/
# /fore/
# /fen_menlun/
# /fjureter/
# /khaggard/
# /khaydegger/
# /khaynlayn/
# /khayiam/
# /haksli/
# /handke/
# /khansson/
# /khanter/
# /kharari/
# /xariton/
# /haritonov/
# /kharms/
# /tomas_kharris/
# /dzhoann_kharris/
# /kharris/
# /hartli/
# /kharchuk/
# /harsha/
# /khashimov/
# /hebbel/
# /kheg/
# /khey/
# /kheyerdal/
# /hejli/
# /heller/
# /hel/
# /heminguej/
# /hemmet/
# /kheraskov/
# /hurst/
# /khetagurov/
# /heath/
# /khill/
# /hill/
# /himenes/
# /khirsh/
# /khmelevskaia/
# /khobb/
# /khodzhes/
# /khoking/
# /khokins/
# /kholidey/
# /kholmirzaev/
# /holmes/
# /khomskiy/
# /khosseyni/
# /khoffman/
# /khusankhodzhaev/
# /huh/
# /khiuz/
# /hagy/
# /cao/
# /cvejg/
# /cvetaeva/
# /tcinberg/
# /cin_chun/
# /jianfu/
# /tcitceron/
# /tcoy/
# /cukmajer/
# /cjuj_ju/
# /tciurupa/
# /qiao_ji/
# /chaykovskiy/
# /chainani/
# /chaldini/
# /chkhan/
# /chandler/
# /chapek/
# /chaplina/
# /charskaia/
# /charushin/
# /chboski/
# /cheyz/
# /chellini/
# /chemeris/
# /chepmen/
# /cherkasov/
# /chernogolovina/
# /chernorizetc/
# /chernyy/
# /chernyshevskij/
# /chesterton/
# /chehov/
# /gobin/
# /chzhen_tinjuj/
# /chigrinov/
# /chiksentmikhayi/
# /chornyy/
# /choser/
# /chudinova/
# /chukovskaja/
# /chukovskij/
# /chukovskiy/
# /chulkov/
# /shaginian/
# /shaig/
# /shalamov/
# /shalev/
# /shamisso/
# /shamiakin/
# /sharma/
# /sharov/
# /sharer/
# /shatobrian/
# /shafer/
# /sheffer/
# /shakhanov/
# /shasha/
# /shvab/
# /shvarc/
# /shvartc/
# /shevchenko/
# /shey/
# /shekli/
# /shekspir/
# /sheldon/
# /shelli/
# /meri_shelli/
# /sher/
# /shergin/
# /sheridan/
# /shefer/
# /shefner/
# /dzunbao/
# /shiller/
# /shinkuba/
# /shishkin/
# /shishkov/
# /shklovskij/
# /shkliarskiy/
# /shlegel/
# /shlink/
# /shmelev/
# /shmitt/
# /shnicler/
# /shoynemann/
# /sholom_aleykhem/
# /sholohov/
# /shopengauer/
# /shou/
# /irvinshou/
# /shpengler/
# /shriharsha/
# /shtilmark/
# /shtifter/
# /strasser/
# /shudraka/
# /shukshin/
# /shukhov/
# /shen_cziczi/
# /shcherba/
# /shcherbakova/
# /ezop/
# /eykhendorf/
# /ekman/
# /eko/
# /ekkholm/
# /elenshleger/
# /eliot/
# /tomaseliot/
# /ellis/
# /elrod/
# /emar/
# /emden/
# /emin/
# /emis/
# /martinemis/
# /engelgardt/
# /ende/
# /enders/
# /erdman/
# /erenburg/
# /eria/
# /ertel/
# /esxil/
# /etvud/
# /eshenbah/
# /esher/
# /eial/
# /juan_chzhen/
# /juan_mej/
# /iudalevich/
# /iudkovskiy/
# /yu_hua/
# /iung/
# /junson/
# /jursenar/
# /bochuan/
# /iazykov/
# /jakobsen/
# /iakovlev/
# /ialom/
# /xianqzhi/
# /ian/
# /ianagikhara/
# /ianovskiy/
# /iansi/
# /ianssen/
# /iansson/
# /iakhina/
# /jashin/
# CPU times: user 2min 3s, sys: 5.84 s, total: 2min 8s
# Wall time: 6min 6s

# %%
import pandas as pd

# %%
books_table = pd.DataFrame(
    {
        "title" : book_titles,
        "author" : book_authors,
        "year" : book_years,
        "tags" : book_tags,
        "summary" : book_texts,
        "summary url" : book_summary_urls,
        "original url" : book_original_urls
    }
)

# %%
books_table
# Out:
#                                                   title  \
# 0                     Мельник — колдун, обманщик и сват
# 1                                                 Алька
# 2                                          Безотцовщина
# 3                                       Братья и сёстры
# 4                                   Две зимы и три лета
# ...                                                 ...
# 2486                                         Нильс Люне
# 2487  На станции Линьцзян, близ реки Сяосян, осенней...
# 2488                            Зулейха открывает глаза
# 2489                                Вологодская свадьба
# 2490                                             Рычаги
#
#                               author     year  \
# 0     Александр Онисимович Аблесимов     1779
# 1        Фёдор Александрович Абрамов     1972
# 2        Фёдор Александрович Абрамов     1961
# 3        Фёдор Александрович Абрамов     1958
# 4        Фёдор Александрович Абрамов     1968
# ...                              ...      ...
# 2486               Енс Петер Якобсен     1880
# 2487                      Ян Сяньчжи  XIII в.
# 2488          Гузель Шамилевна Яхина     2015
# 2489        Александр Яковлевич Яшин     1962
# 2490        Александр Яковлевич Яшин     1956
#
#                                                    tags  \
# 0     Русская лит-ра, 18-й век, Русская литература 1...
# 1       Русская лит-ра, Советская, Советская литература
# 2       Русская лит-ра, Советская, Советская литература
# 3       Русская лит-ра, Советская, Советская литература
# 4       Русская лит-ра, Советская, Советская литература
# ...                                                 ...
# 2486  Скандинавская лит-ра, Датская, Датская литература
# 2487      Азиатская лит-ра, Китай, Китайская литература
# 2488  Русская лит-ра, Российская, Российская литература
# 2489    Русская лит-ра, Советская, Советская литература
# 2490    Русская лит-ра, Советская, Советская литература
#
#                                                 summary  \
# 0     На краю леса перед мельницей мельник Фаддей ст...
# 1     Лето. В последний раз главная героиня Аля Амос...
# 2     Очень кратко: Пятнадцатилетний парень-безотцов...
# 3     Пекашинский мужик Степан Андреянович Ставров с...
# 4     Мишке Пряслину недолго приходилось жить дома. ...
# ...                                                 ...
# 2486  Роман представляет собой историю жизни и искан...
# 2487  Советник Чжан Тянь-цзяо с дочерью Цуй-луань ед...
# 2488  Очень кратко: 1930 год. У молодой татарки убил...
# 2489  Автор приехал в деревню на свадьбу.\nНевесту Г...
# 2490  Вечером в правлении колхоза сидело четверо: бо...
#
#                                             summary url  \
# 0     https://briefly.ru/ablesimov/melnik_koldun_obm...
# 1                      https://briefly.ru/abramov/alka/
# 2          https://briefly.ru/abramov/bezottcovshchina/
# 3           https://briefly.ru/abramov/bratja_i_sestry/
# 4       https://briefly.ru/abramov/dve_zimy_i_tri_leta/
# ...                                                 ...
# 2486            https://briefly.ru/jakobsen/nils_ljune/
# 2487  https://briefly.ru/xianqzhi/dozhd_na_reke_siao...
# 2488  https://briefly.ru/iakhina/zuleykha_otkryvaet_...
# 2489     https://briefly.ru/jashin/vologodskaja_svadba/
# 2490                 https://briefly.ru/jashin/rychagi/
#
#                                            original url
# 0     https://ru.m.wikisource.org/wiki/Мельник_—_кол...
# 1                      http://flibusta.is/b/158027/read
# 2                      http://flibusta.is/b/158029/read
# 3                      http://flibusta.is/b/158030/read
# 4                      http://flibusta.is/b/158033/read
# ...                                                 ...
# 2486                   http://flibusta.is/b/460522/read
# 2487                                               None
# 2488  https://www.litres.ru/pages/quickread/?art=952...
# 2489                                               None
# 2490                   http://flibusta.is/b/466364/read
#
# [2491 rows x 7 columns]

# %%
tags_table = pd.DataFrame({"tag" : sorted(list(set(main_tags)))})
tags_table = tags_table[tags_table.apply(
    lambda row: 'Про' not in row['tag'],
    axis = 1
)]
tags_table.to_csv('tags_table_copy().csv', encoding='utf-8', index=False)

# %%
books_table.to_csv('books_table_copy().csv', encoding='utf-8', index=False)
